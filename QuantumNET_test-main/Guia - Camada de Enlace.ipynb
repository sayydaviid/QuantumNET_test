# %%
from quantumnet.components import Network, Host
from quantumnet.objects import Qubit, Logger
Logger.activate(Logger)

# %%
rede = Network()
rede.set_ready_topology("Grade",3,3)
rede.draw()
# Out:
# 2024-06-11 22:53:31,357: Qubit 0 adicionado à memória do Host 0.
# 2024-06-11 22:53:31,357: Qubit 0 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 0.
# 2024-06-11 22:53:31,357: Qubit 1 adicionado à memória do Host 0.
# 2024-06-11 22:53:31,357: Qubit 1 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 0.
# 2024-06-11 22:53:31,357: Qubit 2 adicionado à memória do Host 0.
# 2024-06-11 22:53:31,357: Qubit 2 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 0.
# 2024-06-11 22:53:31,357: Qubit 3 adicionado à memória do Host 0.
# 2024-06-11 22:53:31,357: Qubit 3 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 0.
# 2024-06-11 22:53:31,357: Qubit 4 adicionado à memória do Host 1.
# 2024-06-11 22:53:31,357: Qubit 4 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 1.
# 2024-06-11 22:53:31,357: Qubit 5 adicionado à memória do Host 1.
# 2024-06-11 22:53:31,366: Qubit 5 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 1.
# 2024-06-11 22:53:31,366: Qubit 6 adicionado à memória do Host 1.
# 2024-06-11 22:53:31,366: Qubit 6 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 1.
# 2024-06-11 22:53:31,366: Qubit 7 adicionado à memória do Host 1.
# 2024-06-11 22:53:31,366: Qubit 7 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 1.
# 2024-06-11 22:53:31,366: Qubit 8 adicionado à memória do Host 2.
# 2024-06-11 22:53:31,366: Qubit 8 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 2.
# 2024-06-11 22:53:31,366: Qubit 9 adicionado à memória do Host 2.
# 2024-06-11 22:53:31,366: Qubit 9 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 2.
# 2024-06-11 22:53:31,366: Qubit 10 adicionado à memória do Host 2.
# 2024-06-11 22:53:31,366: Qubit 10 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 2.
# 2024-06-11 22:53:31,366: Qubit 11 adicionado à memória do Host 2.
# 2024-06-11 22:53:31,366: Qubit 11 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 2.
# 2024-06-11 22:53:31,366: Qubit 12 adicionado à memória do Host 3.
# 2024-06-11 22:53:31,366: Qubit 12 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 3.
# 2024-06-11 22:53:31,374: Qubit 13 adicionado à memória do Host 3.
# 2024-06-11 22:53:31,374: Qubit 13 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 3.
# 2024-06-11 22:53:31,374: Qubit 14 adicionado à memória do Host 3.
# 2024-06-11 22:53:31,374: Qubit 14 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 3.
# 2024-06-11 22:53:31,374: Qubit 15 adicionado à memória do Host 3.
# 2024-06-11 22:53:31,374: Qubit 15 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 3.
# 2024-06-11 22:53:31,374: Qubit 16 adicionado à memória do Host 4.
# 2024-06-11 22:53:31,374: Qubit 16 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 4.
# 2024-06-11 22:53:31,374: Qubit 17 adicionado à memória do Host 4.
# 2024-06-11 22:53:31,374: Qubit 17 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 4.
# 2024-06-11 22:53:31,374: Qubit 18 adicionado à memória do Host 4.
# 2024-06-11 22:53:31,374: Qubit 18 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 4.
# 2024-06-11 22:53:31,374: Qubit 19 adicionado à memória do Host 4.
# 2024-06-11 22:53:31,374: Qubit 19 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 4.
# 2024-06-11 22:53:31,374: Qubit 20 adicionado à memória do Host 5.
# 2024-06-11 22:53:31,382: Qubit 20 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 5.
# 2024-06-11 22:53:31,382: Qubit 21 adicionado à memória do Host 5.
# 2024-06-11 22:53:31,382: Qubit 21 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 5.
# 2024-06-11 22:53:31,382: Qubit 22 adicionado à memória do Host 5.
# 2024-06-11 22:53:31,382: Qubit 22 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 5.
# 2024-06-11 22:53:31,382: Qubit 23 adicionado à memória do Host 5.
# 2024-06-11 22:53:31,382: Qubit 23 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 5.
# 2024-06-11 22:53:31,382: Qubit 24 adicionado à memória do Host 6.
# 2024-06-11 22:53:31,382: Qubit 24 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 6.
# 2024-06-11 22:53:31,382: Qubit 25 adicionado à memória do Host 6.
# 2024-06-11 22:53:31,382: Qubit 25 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 6.
# 2024-06-11 22:53:31,382: Qubit 26 adicionado à memória do Host 6.
# 2024-06-11 22:53:31,382: Qubit 26 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 6.
# 2024-06-11 22:53:31,382: Qubit 27 adicionado à memória do Host 6.
# 2024-06-11 22:53:31,382: Qubit 27 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 6.
# 2024-06-11 22:53:31,390: Qubit 28 adicionado à memória do Host 7.
# 2024-06-11 22:53:31,390: Qubit 28 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 7.
# 2024-06-11 22:53:31,390: Qubit 29 adicionado à memória do Host 7.
# 2024-06-11 22:53:31,390: Qubit 29 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 7.
# 2024-06-11 22:53:31,390: Qubit 30 adicionado à memória do Host 7.
# 2024-06-11 22:53:31,390: Qubit 30 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 7.
# 2024-06-11 22:53:31,390: Qubit 31 adicionado à memória do Host 7.
# 2024-06-11 22:53:31,390: Qubit 31 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 7.
# 2024-06-11 22:53:31,390: Qubit 32 adicionado à memória do Host 8.
# 2024-06-11 22:53:31,390: Qubit 32 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 8.
# 2024-06-11 22:53:31,390: Qubit 33 adicionado à memória do Host 8.
# 2024-06-11 22:53:31,390: Qubit 33 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 8.
# 2024-06-11 22:53:31,398: Qubit 34 adicionado à memória do Host 8.
# 2024-06-11 22:53:31,398: Qubit 34 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 8.
# 2024-06-11 22:53:31,398: Qubit 35 adicionado à memória do Host 8.
# 2024-06-11 22:53:31,398: Qubit 35 criado com fidelidade inicial 0.8616886462013891 e adicionado à memória do Host 8.
# Hosts inicializados
# Canais inicializados

# %%
alice = rede.get_host(1)
bob = rede.get_host(2)
qubit1 = Qubit(1)
qubit2 = Qubit(2)

# %%
rede.physical.entanglement_creation_heralding_protocol(alice,bob)
# Out:
# 2024-06-11 22:53:32,050: A fidelidade entre o qubit Qubit 7 with state None e o qubit Qubit 11 with state None é 0.7425073229923826
# 2024-06-11 22:53:32,050: O protocolo de criação de emaranhamento foi bem sucedido, mas com fidelidade baixa.
# False

# %%
rede.physical.failed_eprs
# Out:
# [(<quantumnet.objects.epr.Epr at 0x1f32648fa50>, 1, 2)]

# %%
rede.linklayer.failed_requests
# Out:
# []

# %%
rede.get_eprs_from_edge(1,2)
# Out:
# []

# %%
rede.linklayer.request(1,2)

# %%
rede.get_eprs_from_edge(1,2)
# Out:
# []

# %%
rede.get_eprs()
# Out:
# {(0, 3): [],
#  (0, 1): [],
#  (1, 4): [],
#  (1, 2): [],
#  (2, 5): [],
#  (3, 6): [],
#  (3, 4): [],
#  (4, 7): [],
#  (4, 5): [],
#  (5, 8): [],
#  (6, 7): [],
#  (7, 8): []}

# %%
# rede.physical.add_epr_to_channel(0,(1,4))

# %%
# rede.physical.add_epr_to_channel(,(1,4))

# %%
# rede.get_eprs()
